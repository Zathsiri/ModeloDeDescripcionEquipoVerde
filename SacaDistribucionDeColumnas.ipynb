# %%
import pandas as pd
from fitter import Fitter, get_common_distributions, get_distributions
#Creamos el dataframe con la bd ya limpia
df = pd.read_csv('out.csv')
df
# Out:
#      Publisher  Semen_Volume  Sperm_Concentration  Total_Number  \
# 0         Tang          5.00               101.00      505.0000
# 1         Tang          2.00                15.00       30.0000
# 2        Baker          2.90               182.00      527.8000
# 3        Auger          4.10                72.00      295.0000
# 4        Auger          2.30                98.00      225.0000
# ...        ...           ...                  ...           ...
# 3127      Swan          4.70                21.70      101.9900
# 3128      Tang          5.00                65.00      325.0000
# 3129      Tang          3.00                 6.00       18.0000
# 3130      Swan          5.92                 5.00       29.6000
# 3131      Swan          7.53                54.55      410.7615
#
#       Total_Motility  Progressive_Motility  Non-progressive_Motility  \
# 0          58.000000             30.000000                 28.000000
# ...

# %%
f = Fitter(df['Normal_Forms'],distributions=['lognorm'])
f.fit()
f.summary()
f.get_best(method = 'sumsquare_error')
# Out:
# Fitting 1 distributions: 100%|████████████████████| 1/1 [00:00<00:00,  4.31it/s]
# {'lognorm': {'s': 0.5142339051068463,
#   'loc': -3.323859205417353,
#   'scale': 16.24097951774136}}

# %%
f = Fitter(df['Non-progressive_Motility'])
f.fit()
f.summary()
f.get_best(method = 'sumsquare_error')
# Out:
# ...
# Fitting 109 distributions:  27%|███▉           | 29/109 [00:11<00:57,  1.40it/s]/Users/migueltanori/opt/anaconda3/lib/python3.9/site-packages/scipy/stats/_continuous_distns.py:3382: IntegrationWarning: The algorithm does not converge.  Roundoff error is detected
#   in the extrapolation table.  It is assumed that the requested tolerance
#   cannot be achieved, and that the returned result (if full_output = 1) is
#   the best which can be obtained.
#   t1 = integrate.quad(llc, -np.inf, x)[0]
# /Users/migueltanori/opt/anaconda3/lib/python3.9/site-packages/scipy/stats/_continuous_distns.py:3382: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   t1 = integrate.quad(llc, -np.inf, x)[0]
# ...
# Fitting 109 distributions:  74%|███████████▏   | 81/109 [02:01<01:40,  3.58s/it]

# %%
f = Fitter(df['Immotile_Spermatozoa'])
f.fit()
f.summary()
f.get_best(method = 'sumsquare_error')

# %%
f = Fitter(df['Normal_Forms'])
f.fit()
f.summary()
f.get_best(method = 'sumsquare_error')

# %%
f = Fitter(df['Semen_Volume'])
f.fit()
f.summary()
f.get_best(method = 'sumsquare_error')

# %%
f = Fitter(df['Sperm_Concentration'],distributions=['beta'])
f.fit()
f.summary()
f.get_best(method = 'sumsquare_error')
# Out:
# Fitting 1 distributions: 100%|████████████████████| 1/1 [00:00<00:00,  4.59it/s]
# {'beta': {'a': 1.8715800118478425,
#   'b': 37123080.61551016,
#   'loc': 0.7219686279350515,
#   'scale': 1562222886.2104893}}
